# %% [markdown]
# # Nigerian household Food Demand System Estimation

# %% [markdown]
# We first need to pip install our requirements.txt to import the necessary packages:

# %%
# %pip install -r requirements.txt -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from eep153_tools.sheets import read_sheets

# %%
NG_URL= "https://docs.google.com/spreadsheets/d/1rbWPdn_Rt3MRoFb_wkomHBcNVmM-3F3lNwCpxP5W_3g/edit?gid=1354121303#gid=1354121303"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

FE_Sheets = ["Food Expenditures (2010Q3)", "Food Expenditures (2011Q1)", "Food Expenditures (2012Q3)", "Food Expenditures (2013Q1)", "Food Expenditures (2015Q3)", "Food Expenditures (2016Q1)"]

FP_Sheets = ["Food Prices (2010Q3)", "Food Prices (2011Q1)", "Food Prices (2012Q3)", "Food Prices (2013Q1)", "Food Prices (2015Q3)", "Food Prices (2016Q1)"]

def prepare_data(NG_URL, FE_Sheet, household_sheet="Household Characteristics"): 
    x = read_sheets(NG_URL, sheet = FE_Sheet)
    d = read_sheets(NG_URL ,sheet = household_sheet)

    # data cleaning to ensure key columns match exactly
    for df in [x, d]:
        df['i'] = pd.to_numeric(df['i'], errors='coerce')
        df['t'] = df['t'].astype(str).str.strip()
        df['m'] = (
            df['m']
            .astype(str)
            .str.strip()
            .str.lower()
            .str.replace(r'\s+', ' ', regex=True)
        )


    d.columns.name = 'k'
    # remove duplicate column names, keep first occurrence
    d = d.loc[:, ~d.columns.duplicated()]

    # collapse duplicate household rows
    d = d.groupby(['i','t','m'], as_index=False).first()

    # Data comes in long format; pivot to wide (one column per food)
    x = x.pivot_table(index=['i','t','m'],columns='j',values='Expenditure',
                   aggfunc='sum')
    x = x.replace(0,np.nan) # Replace zeros with missing

    # Take logs of expenditures; call this y
    y = x

    d.set_index(['i','t','m'],inplace=True)

    # NaN in demographic columns means zero people in that category
    d = d.fillna(0)

    return y, d

# %%
y, d = prepare_data(NG_URL, "Food Expenditures (2016Q1)")

# %%
log_y = np.log(y)

# %%
d.head()
# Out:
# k                        Female 00-03  Female 04-08  Female 09-13  \
# i     t      m
# 10001 2010Q3 south east             1             0             0
#       2011Q1 south east             1             0             0
#       2012Q3 south east             1             0             0
#       2013Q1 south east             0             1             0
#       2015Q3 south east             0             1             0
#
# k                        Female 14-18  Female 19-30  Female 31-50  Female 51+  \
# i     t      m
# 10001 2010Q3 south east             0             1             2           0
#       2011Q1 south east             0             1             2           0
#       2012Q3 south east             0             1             2           0
#       2013Q1 south east             0             1             2           0
#       2015Q3 south east             0             0             2           0
#
# k                        Female NA  Male 00-03  Male 04-08  Male 09-13  \
# i     t      m
# 10001 2010Q3 south east          0           0           0           0
#       2011Q1 south east          0           0           0           0
#       2012Q3 south east          0           0           0           0
#       2013Q1 south east          0           1           0           0
#       2015Q3 south east          1           1           0           0
#
# k                        Male 14-18  Male 19-30  Male 31-50  Male 51+  \
# i     t      m
# 10001 2010Q3 south east           0           1           2         0
#       2011Q1 south east           0           1           2         0
#       2012Q3 south east           0           0           1         2
#       2013Q1 south east           0           0           1         2
#       2015Q3 south east           0           0           0         1
#
# k                        Male NA  log HSize
# i     t      m
# 10001 2010Q3 south east        0   1.945910
#       2011Q1 south east        0   1.945910
#       2012Q3 south east        0   1.945910
#       2013Q1 south east        0   2.079442
#       2015Q3 south east        2   2.079442

# %%
log_y.head()
# Out:
# j                          Apples  Avocado pear  Baby milk powder   Bananas  \
# i     t      m
# 10001 2016Q1 south east       NaN           NaN               NaN  4.210878
# 10002 2016Q1 south east  4.787492           NaN               NaN  4.835033
# 10003 2016Q1 south east       NaN           NaN               NaN  4.605170
# 10004 2016Q1 south east       NaN           NaN               NaN       NaN
# 10005 2016Q1 south east       NaN           NaN               NaN       NaN
#
# j                            Beef  Beer  Biscuits  Bottled water     Bread  \
# i     t      m
# 10001 2016Q1 south east  7.600902   NaN  4.248495            NaN  5.991465
# 10002 2016Q1 south east  6.907755   NaN  5.472671       5.703782  6.396930
# 10003 2016Q1 south east  6.907755   NaN  3.688879       5.010635  5.603241
# 10004 2016Q1 south east  6.907755   NaN  4.248495            NaN  5.577266
# 10005 2016Q1 south east  6.907755   NaN  4.605170            NaN  5.991465
#
# j                        Brown beans  ...  Sweet potatoes       Tea  \
# i     t      m                        ...
# 10001 2016Q1 south east          NaN  ...         5.08136       NaN
# 10002 2016Q1 south east     5.521461  ...             NaN       NaN
# 10003 2016Q1 south east     5.521461  ...             NaN  5.192957
# 10004 2016Q1 south east     5.521461  ...             NaN  5.010635
# 10005 2016Q1 south east     5.703782  ...             NaN  5.010635
#
# j                        Tomato puree (canned)  Tomatoes  Watermelon  \
# i     t      m
# 10001 2016Q1 south east                    NaN  5.005598         NaN
# 10002 2016Q1 south east                    NaN  5.703782    5.422525
# 10003 2016Q1 south east               5.298317  5.181162         NaN
# 10004 2016Q1 south east               5.010635  5.181162         NaN
# 10005 2016Q1 south east               5.010635  5.586627         NaN
#
# j                        Wheat flour  White beans  Wild game meat  Yam flour  \
# i     t      m
# 10001 2016Q1 south east          NaN     5.521461             NaN        NaN
# 10002 2016Q1 south east          NaN          NaN             NaN        NaN
# 10003 2016Q1 south east          NaN          NaN             NaN        NaN
# 10004 2016Q1 south east          NaN          NaN             NaN        NaN
# 10005 2016Q1 south east          NaN          NaN             NaN        NaN
#
# j                        Yam--roots
# i     t      m
# 10001 2016Q1 south east    6.164674
# 10002 2016Q1 south east    6.164674
# 10003 2016Q1 south east    6.159585
# 10004 2016Q1 south east    5.471527
# 10005 2016Q1 south east    6.159585
#
# [5 rows x 102 columns]

# %%
log_y = log_y.stack().dropna()

d = d.stack().dropna()

# %%
from cfe import Regression as rgsn

result = rgsn(y=log_y,d=d)

# %%
result.predicted_expenditures()
# Out:
# i       t       m              j
# 10001   2016Q1  south east     Bananas                   224.848660
#                                Beef                      953.012075
#                                Biscuits                   86.682347
#                                Bread                     416.795418
#                                Brown beans               318.895615
#                                                            ...
# 370040  2016Q1  north central  Tomato puree (canned)     158.065816
#                                Tomatoes                  170.388515
#                                Watermelon                292.245199
#                                White beans               473.464052
#                                Yam--roots               1139.399240
# Length: 195224, dtype: float64

# %%
# %matplotlib widget
df = pd.DataFrame({'y':log_y,'yhat':result.get_predicted_log_expenditures()})
df.plot.scatter(x='yhat',y='y')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
result.get_beta().sort_values()
# Out:
# j
# Pineapples                              0.110004
# Malt drinks                             0.175755
# Kola nut                                0.175997
# Ogbono                                  0.188046
# Groundnut oil                           0.202537
# Palm oil                                0.216506
# Chicken                                 0.222732
# Brown beans                             0.236294
# Pawpaw                                  0.246758
# Soft drinks (Coca Cola, spirit, etc)    0.248809
# Plantains                               0.278037
# Beef                                    0.283670
# Gari                                    0.284542
# Fish--frozen                            0.287839
# Pepper                                  0.323108
# Garden eggs/egg plant                   0.325827
# Other vegetables (fresh or canned)      0.329848
# Eggs                                    0.343187
# Tomato puree (canned)                   0.346697
# Watermelon                              0.356503
# White beans                             0.368739
# Leaves (Cocoyam, Spinach, etc.)         0.379285
# Yam--roots                              0.379928
# Melon                                   0.388442
# Rice--imported                          0.398603
# Sachet water                            0.400628
# Bananas                                 0.428236
# Fish--dried                             0.451120
# Rice--local                             0.458427
# Cocoyam                                 0.461836
# Okra                                    0.474689
# Onions                                  0.476894
# Orange/tangerine                        0.479024
# Biscuits                                0.498288
# Sweet potatoes                          0.505066
# Fish--smoked                            0.532989
# Tomatoes                                0.604561
# Groundnuts                              0.697723
# Fresh Pepper                            0.702553
# Sugar                                   0.881820
# Salt                                    1.051454
# Condiments                              1.103230
# Chocolate drinks                        1.235775
# Milk powder                             1.325240
# Tea                                     1.364900
# Bread                                   1.440482
# Name: beta, dtype: float64

# %%
result.gamma
# Out:
# k                                     Female 00-03  Female 04-08  \
# j
# Bananas                                  -0.073013      0.070019
# Beef                                     -0.004548      0.005960
# Biscuits                                 -0.001854      0.055226
# Bread                                    -0.108352     -0.148544
# Brown beans                              -0.009496      0.036456
# Chicken                                   0.029744      0.111941
# Chocolate drinks                         -0.011696     -0.018085
# Cocoyam                                   0.017506     -0.009624
# Condiments                                0.089226      0.108974
# Eggs                                      0.064844      0.094791
# Fish--dried                              -0.214930     -0.029615
# Fish--frozen                              0.032469     -0.056276
# Fish--smoked                              0.003204      0.047279
# Fresh Pepper                              0.014157      0.018824
# Garden eggs/egg plant                     0.156502      0.024561
# Gari                                     -0.052101      0.017972
# Groundnut oil                             0.028291      0.019200
# Groundnuts                                0.202053      0.212670
# Kola nut                                  0.040253      0.071210
# Leaves (Cocoyam, Spinach, etc.)           0.029068     -0.039331
# Malt drinks                              -0.049617      0.044350
# Melon                                    -0.013473      0.016062
# Milk powder                               0.042068      0.031415
# Ogbono                                    0.072512      0.008439
# Okra                                      0.129469      0.056155
# Onions                                   -0.005704      0.006246
# Orange/tangerine                          0.092258      0.046936
# Other vegetables (fresh or canned)       -0.022188      0.001438
# Palm oil                                  0.052165      0.018596
# Pawpaw                                    0.025977      0.040849
# Pepper                                    0.028203      0.014876
# Pineapples                               -0.039330      0.012394
# Plantains                                -0.074672     -0.070974
# Rice--imported                           -0.022790      0.094675
# Rice--local                               0.023900      0.045607
# Sachet water                             -0.093090     -0.069891
# Salt                                      0.189560      0.189796
# Fish--frozen                           0.177143  6.246440
# Fish--smoked                           0.193180  6.093940
# Fresh Pepper                           0.295553  4.506007
# Garden eggs/egg plant                  0.314200  4.317708
# Gari                                   0.441816  5.603908
# Groundnut oil                          0.238111  5.362586
# Groundnuts                             0.029921  5.112869
# Kola nut                               0.095767  4.491695
# Leaves (Cocoyam, Spinach, etc.)        0.168566  4.794748
# Malt drinks                            0.062261  5.505647
# Melon                                  0.123796  5.294121
# Milk powder                            0.160429  5.399537
# Ogbono                                 0.203231  5.690356
# Okra                                   0.210851  4.761584
# Onions                                 0.264165  4.270754
# Orange/tangerine                       0.036263  4.779767
# Other vegetables (fresh or canned)     0.069822  4.790910
# Palm oil                               0.183317  5.410160
# Pawpaw                                 0.199288  5.259525
# Pepper                                 0.084133  4.331185
# Pineapples                             0.250973  5.580048
# Plantains                              0.355111  5.950567
# Rice--imported                         0.386339  6.617246
# Rice--local                            0.445106  6.503614
# Sachet water                           0.427072  4.540913
# Salt                                   0.256319  2.538466
# Soft drinks (Coca Cola, spirit, etc)   0.197171  5.105453
# Sugar                                  0.016672  4.240752
# Sweet potatoes                         0.143573  5.282859
# Tea                                    0.099664  4.557063
# Tomato puree (canned)                 -0.115093  4.811024
# Tomatoes                               0.233552  5.077613
# Watermelon                             0.313662  5.499472
# White beans                            0.481775  5.884160
# Yam--roots                             0.359416  6.566781

# %%
result.to_pickle('nigerian_result.pickle')

# %%
def get_clean_sheet(sheet=None):

    df = read_sheets(NG_URL,sheet=sheet)
    df.columns = [c.strip() for c in df.columns.tolist()]

    df = df.loc[:,~df.columns.duplicated(keep='first')]

    df = df.drop([col for col in df.columns if col.startswith('Unnamed')], axis=1)

    df = df.loc[~df.index.duplicated(), :]

    return df

# %%
NG_expenditures = get_clean_sheet("Food Expenditures (2016Q1)")

# %%
NG_expenditures.head()
# Out:
#         t              m       i             j  Expenditure
# 0  2016Q1  North central  140088          Beef   500.000000
# 1  2016Q1  North central  140088         Bread   197.368433
# 2  2016Q1  North central  140088          Eggs    60.000000
# 3  2016Q1  North central  140088   Fish--fresh   980.354529
# 4  2016Q1  North central  140088  Fresh Pepper   112.195125

# %%
p = read_sheets(NG_URL, sheet = "Food Prices (2016Q1)")

# %%
import cfe.regression as rgsn
r = rgsn.read_pickle('nigerian_result.pickle')  # Assumes you've already set this up e.g., in Project 3

# %%
pbar = p.groupby('j')['Price'].mean()
pbar = pbar[r.beta.index] # Only use prices for goods we can estimate

# %%
HH_characteristics = read_sheets(NG_URL, sheet = "Household Characteristics")

# %%
FCT = pd.read_csv("NigerianFCT.csv")

# %%
FCT = FCT.rename(columns = {'Unnamed: 0' : 'j'})

# %%
RDI = pd.read_csv('NigerianRDI.csv')

# %%
import numpy as np

xhat = r.predicted_expenditures()

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# %%
xref
# Out:
# np.float64(15619.762191007929)

# %%
qhat = (xhat.unstack('j')/pbar).dropna(how='all')

# Drop missing columns
# i      t      m
# 10001  2016Q1 south east           1.837988  0.027959               0.223161
# 10002  2016Q1 south east           3.304496  0.087541               0.235269
# 10003  2016Q1 south east           2.469352  0.041353               0.209090
# 10004  2016Q1 south east           2.812724  0.043796               0.187149
# 10005  2016Q1 south east           2.225617  0.085083               0.163653
# ...                                     ...       ...                    ...
# 370036 2016Q1 north central        1.313890  0.051965               0.272673
# 370037 2016Q1 north central        0.501567  0.003955               0.111120
# 370038 2016Q1 north central        0.674491  0.012837               0.125185
# 370039 2016Q1 north central        1.101167  0.012043               0.233019
# 370040 2016Q1 north central        1.589560  0.075419               0.223590
#
# j                            Tomatoes  Watermelon  White beans  Yam--roots
# i      t      m
# 10001  2016Q1 south east     1.135049    4.834810     1.296786   10.758984
# 10002  2016Q1 south east     1.726713    5.940646     1.672820   15.378039
# 10003  2016Q1 south east     1.014862    4.810767     1.358221   11.437190
# 10004  2016Q1 south east     1.094369    5.287222     1.244191   11.718531
# 10005  2016Q1 south east     1.219287    5.660818     1.597103   13.385565
# ...                               ...         ...          ...         ...
# 370036 2016Q1 north central  0.759420    5.349193     1.775075   14.254794
# 370037 2016Q1 north central  0.214441    2.757805     0.785947    6.090452
# 370038 2016Q1 north central  0.321005    3.460177     0.917241    7.078883
# 370039 2016Q1 north central  0.442832    3.955526     1.623972   14.392885
# 370040 2016Q1 north central  0.774362    5.813431     1.906641   15.599987
#
# [4244 rows x 46 columns]

# %%
def my_prices(p0, p=pbar, j=None):
    p = p.copy()
    if j is not None:
        p.loc[j] = p0
    return p

# %%
r.demands(xref,pbar)
# Out:
# j
# Bananas                                 0.938295
# Beef                                    0.952433
# Biscuits                                0.323108
# Bread                                   0.597134
# Brown beans                             1.087958
# Chicken                                 1.042662
# Chocolate drinks                        0.054494
# Cocoyam                                 1.067173
# Condiments                              0.090689
# Eggs                                    0.505140
# Fish--dried                             0.607532
# Fish--frozen                            0.978286
# Fish--smoked                            0.717188
# Fresh Pepper                            0.467611
# Garden eggs/egg plant                   0.936737
# Gari                                    0.954628
# Groundnut oil                           0.881283
# Groundnuts                              0.330448
# Kola nut                                0.648638
# Leaves (Cocoyam, Spinach, etc.)         1.004908
# Malt drinks                             0.933755
# Melon                                   0.351820
# Milk powder                             0.048106
# Ogbono                                  0.590996
# Okra                                    0.334511
# Onions                                  0.781184
# Orange/tangerine                        1.176028
# Other vegetables (fresh or canned)      0.994175
# Palm oil                                0.910872
# Pawpaw                                  1.177872
# Pepper                                  0.436319
# Pineapples                              1.107428
# Plantains                               1.045481
# Rice--imported                          1.399964
# Rice--local                             1.584057
# Sachet water                            2.048758
# Salt                                    0.073129
# Soft drinks (Coca Cola, spirit, etc)    0.989122
# Sugar                                   0.193312
# Sweet potatoes                          1.162590
# Tea                                     0.007819
# Tomato puree (canned)                   0.534387
# Tomatoes                                0.797779
# Watermelon                              1.722027
# White beans                             1.121889
# Yam--roots                              2.322833
# Name: quantities, dtype: float64

# %%
import numpy as np

# %matplotlib inline

plt.close('all')          # optional: closes old figures
plt.figure(figsize=(8,6)) # start a new clean figure

use = 'Bananas'   # Good we want demand curve for
scale = np.linspace(0.5, 2, 20)

plt.close('all')
plt.figure(figsize=(8,6))

# Median budget household
median_demands = [
    r.demands(
        xref,
        my_prices(pbar[use] * s, pbar, j=use)
    )[use]
    for s in scale
]

# 25th percentile household
q25_demands = [
    r.demands(
        xbar.quantile(0.25),
        my_prices(pbar[use] * s, pbar, j=use)
    )[use]
    for s in scale
]

# 75th percentile household
q75_demands = [
    r.demands(
        xbar.quantile(0.75),
        my_prices(pbar[use] * s, pbar, j=use)
    )[use]
    for s in scale
]

# Plot all three demand curves
plt.plot(median_demands, scale, marker='o', label='Median Budget')
plt.plot(q25_demands, scale, marker='o', label='25th Percentile Budget')
plt.plot(q75_demands, scale, marker='o', label='75th Percentile Budget')

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of {use} Demanded (Kgs)")
plt.title(f"Demand Curves for {use}")
plt.legend()
plt.grid(True)

plt.show()

# %%
fig,ax = plt.subplots()

scale = np.geomspace(0.01,100,100)
ax.plot(np.log(scale),[(r.expenditures(s*xref,pbar)/(s*xref))['Bananas'] for s in scale])
ax.set_xlabel(f'log budget (relative to base of {xref:.0f})')
ax.set_ylabel(f'Expenditure share')
ax.set_title('Engel Curves')
# Out:
# /srv/conda/lib/python3.11/site-packages/consumerdemands/root_with_precision.py:83: UserWarning: Tolerance is set to 1.00E-12.  Change in value is -2.98E-08.  Iterations are 1001.  Perhaps tolerance is too high?
#   warn("Tolerance is set to %.2E.  Change in value is %.2E.  Iterations are %d.  Perhaps tolerance is too high?" % (tol,x[0]-x[-1],i))
# /srv/conda/lib/python3.11/site-packages/consumerdemands/root_with_precision.py:83: UserWarning: Tolerance is set to 1.00E-12.  Change in value is -7.45E-09.  Iterations are 1001.  Perhaps tolerance is too high?
#   warn("Tolerance is set to %.2E.  Change in value is %.2E.  Iterations are %d.  Perhaps tolerance is too high?" % (tol,x[0]-x[-1],i))
# /srv/conda/lib/python3.11/site-packages/consumerdemands/root_with_precision.py:83: UserWarning: Tolerance is set to 1.00E-12.  Change in value is -3.73E-09.  Iterations are 1001.  Perhaps tolerance is too high?
#   warn("Tolerance is set to %.2E.  Change in value is %.2E.  Iterations are %d.  Perhaps tolerance is too high?" % (tol,x[0]-x[-1],i))
# /srv/conda/lib/python3.11/site-packages/consumerdemands/root_with_precision.py:83: UserWarning: Tolerance is set to 1.00E-12.  Change in value is -1.86E-09.  Iterations are 1001.  Perhaps tolerance is too high?
#   warn("Tolerance is set to %.2E.  Change in value is %.2E.  Iterations are %d.  Perhaps tolerance is too high?" % (tol,x[0]-x[-1],i))
# /srv/conda/lib/python3.11/site-packages/consumerdemands/root_with_precision.py:83: UserWarning: Tolerance is set to 1.00E-12.  Change in value is -7.28E-12.  Iterations are 1001.  Perhaps tolerance is too high?
#   warn("Tolerance is set to %.2E.  Change in value is %.2E.  Iterations are %d.  Perhaps tolerance is too high?" % (tol,x[0]-x[-1],i))
# Text(0.5, 1.0, 'Engel Curves')
